# %%
import numpy as np
import pandas as pd

# %%
route = pd.read_csv(r"C:\Users\Priya\Downloads\DATA SETS\correct.csv")

# %%
route.head()
# Out:
#    time_step  distance_remaining  speed weather_condition  \
# 0          0             499.859  50.60             sunny
# 1         10             499.679  64.85             sunny
# 2         20             499.536  51.42             sunny
# 3         30             499.460  27.36            cloudy
# 4         40             499.267  69.48             clear
#
#   road_traffic_density vehicle_condition festival  time_taken  delay_remaining
# 0                 high              good       no          -2             4.31
# 1             moderate              good       no           8             2.65
# 2                  low              poor       no          18             7.44
# 3                  jam              good       no          31             1.06
# 4                  low              good      yes          42             4.90

# %%
route.tail()
# Out:
#        time_step  distance_remaining  speed weather_condition  \
# 99995     999950                 0.0    0.0             clear
# 99996     999960                 0.0    0.0             clear
# 99997     999970                 0.0    0.0             clear
# 99998     999980                 0.0    0.0             clear
# 99999     999990                 0.0    0.0             clear
#
#       road_traffic_density vehicle_condition festival  time_taken  \
# 99995                  low              good       no      999950
# 99996                  low              good       no      999959
# 99997                  low              good       no      999969
# 99998                  low              good       no      999981
# 99999                  low              good       no      999989
#
#        delay_remaining
# 99995              0.0
# 99996              0.0
# 99997              0.0
# 99998              0.0
# 99999              0.0
